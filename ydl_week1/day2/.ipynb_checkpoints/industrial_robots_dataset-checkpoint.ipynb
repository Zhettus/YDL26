# %%
  import kagglehub
  import pandas as pd
  import os

  # Get the path to the downloaded dataset
  path = kagglehub.dataset_download("kennedywanakacha/industrial-robotics-and-au
  tomation-dataset")
  
  # List files to confirm what's available
  print(os.listdir(path))

  # Load the CSV file
  df = pd.read_csv(os.path.join(path, "robotics_data.csv"))
  df.head()
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████| 730/730 [00:00<00:00, 1.10MB/s]
# Extracting files...
# Path to dataset files: /Users/zadyra/.cache/kagglehub/datasets/kennedywanakacha/industrial-robotics-and-automation-dataset/versions/1

# %%
pip install kagglehub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]
# ...
# Note: you may need to restart the kernel to use updated packages.
